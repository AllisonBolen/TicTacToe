# %%
import numpy as np
import math, os, pickle
from itertools import product
import functools
import collections

from random import randint
import datetime, random

# %% [markdown]
# Your state table is: states × actions  matrix.
#
# you have 9! states and 9 actions becasue each action is being placed on a spot on the board
#
# we will have a q table and a reward table same dimensions

# %%
states = math.factorial(9) 
states = 3**9
actions = list(product([0,1,2],[0,1,2]))

state_name_dict = load_objects("./stateDict.pkl")

initial_q_table = np.zeros((len(state_name_dict),len(actions)))

# %%
def load_objects(file):
    with open(file, 'rb') as input:
        return pickle.load(input)
    
def save_it_all(obj, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, 'wb') as output:  # Overwrites any existing file.

        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

# %%
board = []
for row in range(0, 3):
    board.append(["-","-","-"])
condition = True
while condition:
    x = randint(0, 2)
    y = randint(0, 2)
    condition =  board[x][y] != "-"

board[x][y] = "O"

# %%
k = dict()
k["a"] = 4
k.get("a",0.0)
# Out:
# 4

# %%
Q = np.zeros(shape=(3, 3))

# %%
action = np.argmax(
                    Q[state, :] + np.random.randn(1, 2) * (1./(i + 1)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-30b82b18efef> in <module>
#       1 action = np.argmax(
# ----> 2                     Q[state, :] + np.random.randn(1, 2) * (1./(i + 1)))
#
# NameError: name 'state' is not defined

# %%
collections.defaultdict(int)
# Out:
# defaultdict(int, {})

# %%
s = 'xoxo-o-ox'
a = actions
actions[0]
# Out:
# (0, 0)

# %%
c = a[0]*3+a[1]

# %%
a[1]
# Out:
# (0, 1)

# %%
s[3] == "-"
# Out:
# False

# %%
[a for a in actions if s[a[0]*3 + a[1]] == '-']
# Out:
# [(1, 1), (2, 0)]

# %%
random.random()
# Out:
# 0.46805439853600583

# %%
actions = list(product([0,1,2],[0,1,2]))
Q = {}
# initialize all action values to zero
for action in actions:
    Q[action] = collections.defaultdict(int)

# %%
valid_actions = [a for a in actions if s[a[0]*3 + a[1]] == '-']
values = np.array([Q[a][s] for a in valid_actions])
values[2] +=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-890e5d428d44> in <module>
#       1 valid_actions = [a for a in actions if s[a[0]*3 + a[1]] == '-']
#       2 values = np.array([Q[a][s] for a in valid_actions])
# ----> 3 values[2] +=1
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
s = '-------x-'

# %%
values
# Out:
# array([0, 0])

# %%
np.max(values)
# Out:
# 0

# %%
ix_max = np.where(values == np.max(values))[0]
ix_max
# Out:
# array([0, 1])

# %%
"-" not in "xoxoxoxox"
# Out:
# True

# %%
not False
# Out:
# True

# %%
not 0 == -1
# Out:
# True

# %%
1.-.2
# Out:
# 0.8

# %%
agentO = load_objects("./agentO.pkl")
agentX = load_objects("./agentX.pkl")

# %%
agentX.rewards
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  10,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
# ...

# %%
test = .5 
for x in range(10):
    test*=1.-0.02
